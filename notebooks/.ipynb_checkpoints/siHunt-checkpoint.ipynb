# %%
import pycmap
api = pycmap.API(token='19e91d80-ae64-12e9-8f77-f3e8f5c1f730', vizEngine='plotly')

# %%
from pycmap.viz import plot_timeseries

go = plot_timeseries(
                    tables=['tblPisces_NRT', 'tblPisces_NRT', 'tblPisces_NRT', 'tblPisces_NRT', 'tblPisces_NRT', 'tblPisces_NRT'], 
                    variables=['Si', 'NO3', 'Fe', 'PO4', 'O2', 'CHL'], 
                    dt1='2012-01-01', 
                    dt2='2019-05-30', 
                    lat1=30, 
                    lat2=35, 
                    lon1=-160, 
                    lon2=-158, 
                    depth1=0, 
                    depth2=0.5, 
                    exportDataFlag=False,
                    show=True,
                    interval='m'
                    )
# Out:
# ...
# 1: Si retrieved (tblPisces_NRT).
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="b49781fa-a1cb-41fe-b5ac-b20c087af678" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(go[2].x, go[2].y, 'o')
plt.ylim(0, 7e-5)
# Out:
# (0, 7e-05)

# %%
go = plot_timeseries(
                    tables=['tblPisces_NRT', 'tblPisces_NRT', 'tblPisces_NRT', 'tblPisces_NRT', 'tblPisces_NRT', 'tblPisces_NRT'], 
                    variables=['Si', 'NO3', 'Fe', 'PO4', 'O2', 'CHL'], 
                    dt1='2012-01-01', 
                    dt2='2019-05-30', 
                    lat1=40, 
                    lat2=45, 
                    lon1=-160, 
                    lon2=-158, 
                    depth1=0, 
                    depth2=0.5, 
                    exportDataFlag=False,
                    show=True,
                    interval='m'
                    )
# Out:
# ...
# 1: Si retrieved (tblPisces_NRT).
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="da5ba4fb-cb56-4131-95f4-9d505e23dbdd" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(go[2].x, go[2].y, 'o')
plt.ylim(6e-6, 3e-5)
# Out:
# (6e-06, 3e-05)

# %%
go = plot_timeseries(
                    tables=['tblPisces_NRT', 'tblPisces_NRT', 'tblPisces_NRT', 'tblPisces_NRT', 'tblPisces_NRT', 'tblPisces_NRT'], 
                    variables=['Si', 'NO3', 'Fe', 'PO4', 'O2', 'CHL'], 
                    dt1='2012-01-01', 
                    dt2='2019-05-30', 
                    lat1=22, 
                    lat2=27, 
                    lon1=-160, 
                    lon2=-158, 
                    depth1=0, 
                    depth2=0.5, 
                    exportDataFlag=False,
                    show=True,
                    interval='m'
                    )
# Out:
# ...
# 1: Si retrieved (tblPisces_NRT).
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="6ce0cd8f-8ba0-433d-922d-c01cf0462c6f" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(go[2].x, go[2].y, 'o')
plt.ylim(6e-6, 2e-4)
# Out:
# (6e-06, 0.0002)

# %%
go = plot_timeseries(
                    tables=['tblCHL_REP'], 
                    variables=['chl'], 
                    dt1='2012-01-01', 
                    dt2='2018-05-30', 
                    lat1=22, 
                    lat2=27, 
                    lon1=-160, 
                    lon2=-158, 
                    depth1=0, 
                    depth2=0.5, 
                    exportDataFlag=False,
                    show=True,
                    interval='m'
                    )
# Out:
# ...
# 1: chl retrieved (tblCHL_REP).
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="eee12335-201e-44d4-b699-d85ab20d0803" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
# ...

# %%
go = plot_timeseries(
                    tables=['tblCHL_REP'], 
                    variables=['chl'], 
                    dt1='2012-01-01', 
                    dt2='2018-05-30', 
                    lat1=30, 
                    lat2=35, 
                    lon1=-160, 
                    lon2=-158, 
                    depth1=0, 
                    depth2=0.5, 
                    exportDataFlag=False,
                    show=True,
                    interval='m'
                    )
# Out:
# ...
# 1: chl retrieved (tblCHL_REP).
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="d9e5fbae-831e-4dc1-a5e5-a97961faf9e5" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
# ...

# %%
go = plot_timeseries(
                    tables=['tblCHL_REP'], 
                    variables=['chl'], 
                    dt1='2012-01-01', 
                    dt2='2018-05-30', 
                    lat1=40, 
                    lat2=45, 
                    lon1=-160, 
                    lon2=-158, 
                    depth1=0, 
                    depth2=0.5, 
                    exportDataFlag=False,
                    show=True,
                    interval='a'
                    )
# Out:
# ...
# 1: chl retrieved (tblCHL_REP).
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="130ba74c-50f4-4717-a624-b23b5fb2b242" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
# ...

# %%
from pycmap.viz import plot_timeseries

go = plot_timeseries(
                    tables=['tblDarwin_Nutrient'], 
                    variables=['SiO2'], 
                    dt1='2012-01-01', 
                    dt2='2015-12-30', 
                    lat1=30, 
                    lat2=35, 
                    lon1=-160, 
                    lon2=-158, 
                    depth1=0, 
                    depth2=5, 
                    exportDataFlag=False,
                    show=True,
                    interval='m'
                    )
# Out:
# ...
# 1: SiO2 retrieved (tblDarwin_Nutrient).
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="17364439-950a-4092-b504-847e4a307c3e" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
# ...

# %%
from pycmap.viz import plot_timeseries

go = plot_timeseries(
                    tables=['tblHOT_ParticleFlux'], 
                    variables=['silica_hot'], 
                    dt1='1988-12-01', 
                    dt2='2016-10-15', 
                    lat1=22, 
                    lat2=23, 
                    lon1=-159, 
                    lon2=-157, 
                    depth1=71, 
                    depth2=150, 
                    exportDataFlag=False,
                    show=True,
                    interval=''
                    )
# Out:
# ...
# 1: silica_hot retrieved (tblHOT_ParticleFlux).
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="6842a10b-a4d5-4851-af7b-affc8a3f5fc1" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(go[0].x, go[0].y, 'o')
plt.ylim(0, 10)
# Out:
# (0, 10)

# %%
from pycmap.viz import plot_timeseries

go = plot_timeseries(
                    tables=['tblHOT_Bottle', 'tblHOT_Bottle'], 
                    variables=['SiO4_bottle_hot', 'psi_bottle_hot'], 
                    dt1='1988-12-01', 
                    dt2='2016-10-15', 
                    lat1=22, 
                    lat2=23, 
                    lon1=-159, 
                    lon2=-157, 
                    depth1=0, 
                    depth2=0, 
                    exportDataFlag=False,
                    show=True,
                    interval=''
                    )
# Out:
# ...
# 1: SiO4_bottle_hot retrieved (tblHOT_Bottle).
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="159aee28-1be1-4a15-9e66-c18c2ba7c1e8" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(go[1].x, go[1].y, 'o')
plt.ylim(0, 25)
# Out:
# (0, 25)
